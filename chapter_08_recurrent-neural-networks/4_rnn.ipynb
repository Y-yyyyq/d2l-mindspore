# %% [markdown]
# # 循环神经网络

# %%
import sys
sys.path.append('..')

# %%
import mindspore
import mindspore.mint as mint
from d2l import mindspore as d2l

X, W_xh = mint.randn((3, 1)), mint.randn((1, 4))
H, W_hh = mint.randn((3, 4)), mint.randn((4, 4))
mint.matmul(X, W_xh) + mint.matmul(H, W_hh)
# Out:
# Tensor(shape=[3, 4], dtype=Float32, value=
# [[-3.39013159e-01, -1.00202858e+00, -1.87027231e-01, -3.71970654e+00],
#  [ 1.77698231e+00, -8.22008550e-02, -7.30265856e-01,  1.31694555e+00],
#  [-1.75439298e-01,  1.53404427e+00, -1.31514513e+00,  2.31721973e+00]])

# %%
mint.matmul(mint.cat((X, H), 1), mint.cat((W_xh, W_hh), 0))
# Out:
# Tensor(shape=[3, 4], dtype=Float32, value=
# [[-3.39013159e-01, -1.00202847e+00, -1.87027231e-01, -3.71970654e+00],
#  [ 1.77698243e+00, -8.22008550e-02, -7.30265796e-01,  1.31694543e+00],
#  [-1.75439283e-01,  1.53404438e+00, -1.31514513e+00,  2.31721973e+00]])
